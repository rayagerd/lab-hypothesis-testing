# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import pandas as pd
import numpy as np
import scipy.stats as st
import statsmodels.api as sm
from scipy.stats import trim_mean, mode, skew, gaussian_kde, pearsonr, spearmanr, beta
from statsmodels.stats.weightstats import ztest as ztest

from scipy.stats import ttest_ind, norm, t
from scipy.stats import f_oneway
from scipy.stats import sem

# %% [markdown]
# # Challenge 1
#
# This is a placeholder to make the AI corrector be able to find the correct exercise for feedback

# %%
# Run this code:
salaries = pd.read_csv('../data/Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %%
salaries.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    Annual Salary  Hourly Rate
# 0       101442.0          NaN
# 1        94122.0          NaN
# 2       101592.0          NaN
# 3       110064.0          NaN
# ...

# %%
salaries.sample(7)
# Out:
#                        Name                                     Job Titles  \
# 7688       DREW,  WILLIAM D                     STAFF ASST TO THE ALDERMAN
# 1305      BAGDADE,  GREGG R  FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC
# 4017      CAPILLA,  MARIO A                BUILDING/CONSTRUCTION INSPECTOR
# 902           APEL,  JOHN F             AVIATION SECURITY OFFICER - HOURLY
# 29614       TIRADO,  JOSE M                                     LIEUTENANT
# 24115      RAMOS,  ARTHUR J                     OPERATING ENGINEER-GROUP A
# 18696  MCCOY JR,  CLARENCE               POLICE OFFICER / FLD TRNG OFFICER
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 7688       CITY COUNCIL                 F           Salary            NaN
# 1305               FIRE                 F           Salary            NaN
# 4017          BUILDINGS                 F           Salary            NaN
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Your code here
hourly_sample = salaries[salaries['Salary or Hourly']=='Hourly'].sample(30)

# %%
hourly_sample.head()
# Out:
#                        Name                  Job Titles     Department  \
# 8443         EVANS,  JOHN E     POOL MOTOR TRUCK DRIVER  STREETS & SAN
# 26683   SCHNEIDER,  GLENN L  OPERATING ENGINEER-GROUP C    WATER MGMNT
# 2813       BRAGG,  MONTANA             CUSTODIAL WORKER       AVIATION
# 9326        FRAIRE,  ANGEL            HOISTING ENGINEER    WATER MGMNT
# 22396  PANNARALE,  VICTOR A         FOREMAN OF PAINTERS    WATER MGMNT
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 8443                  F           Hourly           40.0            NaN
# 26683                 F           Hourly           40.0            NaN
# 2813                  F           Hourly           40.0            NaN
# 9326                  F           Hourly           40.0            NaN
# 22396                 F           Hourly           40.0            NaN
#
#        Hourly Rate
# 8443         35.60
# 26683        45.07
# 2813         14.15
# 9326         49.10
# ...

# %%
hourly_sample['Hourly Rate'].mean()
# Out:
# np.float64(32.50066666666667)

# %%
result = st.ttest_1samp(hourly_sample['Hourly Rate'],30)
result
# Out:
# TtestResult(statistic=np.float64(1.002554864549123), pvalue=np.float64(0.32436814979611106), df=np.int64(29))

# %%
if result.pvalue < 0.05:
    print("HO is rejected")
else:
    print("H0 is validated")
# Out:
# H0 is validated

# %% [markdown]
# # Challenge 3
#
# This is a placeholder to make the AI corrector be able to find the correct exercise for feedback

# %% [markdown]
# # Challenge 4 -  Hypothesis Tests of Proportions
#
# ## This challenge is OPTIONAL
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here
count_hourly = len(salaries[salaries['Salary or Hourly']=='Hourly'] and )
count_hourly
# Out:
# 8022

# %%
total = salaries.shape[0]
total
# Out:
# 33183

# %%
sm.stats.proportions_ztest(count_hourly, total, value=0.25)
# Out:
# (np.float64(-3.5099964213703005), np.float64(0.00044811272490579676))

# %%
# -> z-statistic is -3.5 which should mean that the number of hourly workers in the City of Chicago 
# is significantly different from 25%
